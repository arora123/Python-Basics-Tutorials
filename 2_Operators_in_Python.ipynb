# %% [markdown]
# <a href="https://colab.research.google.com/github/arora123/Python-Basics-Tutorials/blob/main/2_Operators_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Operators in Python
#
# 1. Mathematical Operators
# 2. Comparision Operators
# 3. Boolean Operators
#
# image sources: Python All in One_for Dummies by John Shovic and Alan Simpson

# %% [markdown]
# ##Mathematical Operators
#
# ![image.png](data:image/png;base64,...)

# %%
25-35
# Out:
# -10

# %%
5*2
# Out:
# 10

# %%
10/2
# Out:
# 5.0

# %%
12 // 5
# Out:
# 2

# %%
12 % 5
# Out:
# 2

# %%
2**5
# Out:
# 32

# %% [markdown]
# ## Comparison Operators
#
# ![image.png](data:image/png;base64,...)

# %%
23 < 56
# Out:
# True

# %%
45 >98
# Out:
# False

# %%
45 == 45
# Out:
# True

# %%
23 != 20 + 3
# Out:
# False

# %% [markdown]
# ##Boolean Operator
# ![image.png](data:image/png;base64,...)

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not True
# Out:
# False
